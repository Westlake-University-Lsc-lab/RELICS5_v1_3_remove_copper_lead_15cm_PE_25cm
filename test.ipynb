# %%
import numpy as np

# %%
#shapping ring
1.34303*17
# Out:
# 22.831509999999998

# %%
# steel
18.0959+8.51623+590.5/1e6+13.5837/1e3+310.436/1e6+620.733/1e6+621.704/1e6+15.678+15.678+ 6.37045+30.276+150.248*6/1e3
# Out:
# 95.53179507300001

# %%
95.53179507300001*1000/8
# Out:
# 11941.474384125002

# %%
# outer container，including pipe
30.276+6.37045+18.0959+150.248*6/1e3
# Out:
# 55.643838

# %%
(30.276+6.37045+18.0959+150.248*6/1e3)*1000/8
# Out:
# 6955.47975

# %%
# inner container
15.678+15.678+8.51623
# Out:
# 39.87223

# %%
39.87223*1000/8
# Out:
# 4984.02875

# %%
# flange
343.224*6/1e3
# Out:
# 2.059344

# %%
343.224*6/1e3 *1000/8
# Out:
# 257.418

# %%
# Teflon
(153.138+59.8211+978.011+59.887)/1000
# Out:
# 1.2508571

# %%
(153.138+59.8211+978.011+59.887)/2.2
# Out:
# 568.571409090909

# %%
# LXe
21.6433+8.57839
# Out:
# 30.221690000000002

# %%
30.221690000000002*1000/2.862
# Out:
# 10559.640111809924

# %%
21.6433*1000/2.862
# Out:
# 7562.299091544374

# %%
8.57839*1000/2.862
# Out:
# 2997.341020265549
